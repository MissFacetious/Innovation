# %%
import pandas as pd
import difflib
pd.set_option('display.max_rows', 300)
pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv('../data/electrification.csv', skiprows=4)

# %%
df.head()
# Out:
#   Country Name Country Code                           Indicator Name  \
# 0        Aruba          ABW  Access to electricity (% of population)
# 1  Afghanistan          AFG  Access to electricity (% of population)
# 2       Angola          AGO  Access to electricity (% of population)
# 3      Albania          ALB  Access to electricity (% of population)
# 4      Andorra          AND  Access to electricity (% of population)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  \
# 0  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1970  1971  1972  1973  1974  1975  1976  1977  1978  1979  1980  1981  \
# ...

# %%
df.drop(columns=['Country Name', 'Indicator Name', 'Indicator Code'], inplace=True)

# %%
df.rename(columns={'Country Code': 'country_iso'}, inplace=True)

# %%
df_new = df.melt(id_vars=["country_iso"], var_name="year", value_name="electrification")
df_new
# Out:
#       country_iso  year  electrification
# 0             ABW  1960              NaN
# 1             AFG  1960              NaN
# 2             AGO  1960              NaN
# 3             ALB  1960              NaN
# 4             AND  1960              NaN
# ...           ...   ...              ...
# 15835         XKX  2019              NaN
# 15836         YEM  2019              NaN
# 15837         ZAF  2019              NaN
# 15838         ZMB  2019              NaN
# 15839         ZWE  2019              NaN
#
# [15840 rows x 3 columns]

# %%
df_new.dropna(inplace=True)

# %%
df_new.to_csv('../data/converted/electrification.csv', index=False)

# %%
df_saved = pd.read_csv('../data/converted/electrification.csv')
df_saved
# Out:
#      country_iso  year  electrification
# 0            ABW  1990       100.000000
# 1            ALB  1990       100.000000
# 2            AND  1990       100.000000
# 3            ARE  1990       100.000000
# 4            AUS  1990       100.000000
# ...          ...   ...              ...
# 6015         XKX  2017       100.000000
# 6016         YEM  2017        79.200000
# 6017         ZAF  2017        84.400000
# 6018         ZMB  2017        40.300000
# 6019         ZWE  2017        40.421368
#
# [6020 rows x 3 columns]
