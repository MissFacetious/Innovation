# %%
import pandas as pd
import difflib
pd.set_option('display.max_rows', 300)
pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv('../data/secure_internet_servers.csv', skiprows=4)

# %%
df.head()
# Out:
#   Country Name Country Code                                  Indicator Name  \
# 0        Aruba          ABW  Secure Internet servers (per 1 million people)
# 1  Afghanistan          AFG  Secure Internet servers (per 1 million people)
# 2       Angola          AGO  Secure Internet servers (per 1 million people)
# 3      Albania          ALB  Secure Internet servers (per 1 million people)
# 4      Andorra          AND  Secure Internet servers (per 1 million people)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  \
# 0  IT.NET.SECR.P6   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  IT.NET.SECR.P6   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  IT.NET.SECR.P6   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  IT.NET.SECR.P6   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  IT.NET.SECR.P6   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
df.drop(columns=['Country Name', 'Indicator Name', 'Indicator Code'], inplace=True)

# %%
df.rename(columns={'Country Code': 'country_iso'}, inplace=True)

# %%
df = df.melt(id_vars=["country_iso"], var_name="year", value_name="secure_internet_servers")
df
# Out:
#       country_iso         year  secure_internet_servers
# 0             ABW         1960                      NaN
# 1             AFG         1960                      NaN
# 2             AGO         1960                      NaN
# 3             ALB         1960                      NaN
# 4             AND         1960                      NaN
# ...           ...          ...                      ...
# 16099         XKX  Unnamed: 64                      NaN
# 16100         YEM  Unnamed: 64                      NaN
# 16101         ZAF  Unnamed: 64                      NaN
# 16102         ZMB  Unnamed: 64                      NaN
# 16103         ZWE  Unnamed: 64                      NaN
#
# [16104 rows x 3 columns]

# %%
df.dropna(inplace=True)
df
# Out:
#       country_iso  year  secure_internet_servers
# 13200         ABW  2010                88.522558
# 13201         AFG  2010                 0.479690
# 13202         AGO  2010                 1.284453
# 13203         ALB  2010                 4.119435
# 13204         AND  2010               686.805054
# ...           ...   ...                      ...
# 15570         WSM  2018               535.359201
# 15572         YEM  2018                 3.754559
# 15573         ZAF  2018             12034.277414
# 15574         ZMB  2018                41.206047
# 15575         ZWE  2018                46.609818
#
# [2315 rows x 3 columns]

# %%
df.to_csv('../data/converted/secure_internet_servers.csv', index=False)

# %%
df_saved = pd.read_csv('../data/converted/secure_internet_servers.csv')
df_saved
# Out:
#      country_iso  year  secure_internet_servers
# 0            ABW  2010                88.522558
# 1            AFG  2010                 0.479690
# 2            AGO  2010                 1.284453
# 3            ALB  2010                 4.119435
# 4            AND  2010               686.805054
# ...          ...   ...                      ...
# 2310         WSM  2018               535.359201
# 2311         YEM  2018                 3.754559
# 2312         ZAF  2018             12034.277414
# 2313         ZMB  2018                41.206047
# 2314         ZWE  2018                46.609818
#
# [2315 rows x 3 columns]
