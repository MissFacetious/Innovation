# %%
import pandas as pd
import difflib
pd.set_option('display.max_rows', 300)
pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv('../data/school_enrollment_tertiary.csv', skiprows=4)

# %%
df.head()
# Out:
#   Country Name Country Code                         Indicator Name  \
# 0        Aruba          ABW  School enrollment, tertiary (% gross)
# 1  Afghanistan          AFG  School enrollment, tertiary (% gross)
# 2       Angola          AGO  School enrollment, tertiary (% gross)
# 3      Albania          ALB  School enrollment, tertiary (% gross)
# 4      Andorra          AND  School enrollment, tertiary (% gross)
#
#   Indicator Code  1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  \
# 0    SE.TER.ENRR   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1    SE.TER.ENRR   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2    SE.TER.ENRR   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3    SE.TER.ENRR   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4    SE.TER.ENRR   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#       1970      1971      1972     1973    1974     1975     1976     1977  \
# ...

# %%
df.drop(columns=['Country Name', 'Indicator Name', 'Indicator Code'], inplace=True)

# %%
df.rename(columns={'Country Code': 'country_iso'}, inplace=True)

# %%
df = df.melt(id_vars=["country_iso"], var_name="year", value_name="school_enrollment_tertiary")
df
# Out:
#       country_iso  year  school_enrollment_tertiary
# 0             ABW  1960                         NaN
# 1             AFG  1960                         NaN
# 2             AGO  1960                         NaN
# 3             ALB  1960                         NaN
# 4             AND  1960                         NaN
# ...           ...   ...                         ...
# 15835         XKX  2019                         NaN
# 15836         YEM  2019                         NaN
# 15837         ZAF  2019                         NaN
# 15838         ZMB  2019                         NaN
# 15839         ZWE  2019                         NaN
#
# [15840 rows x 3 columns]

# %%
df.dropna(inplace=True)
df
# Out:
#       country_iso  year  school_enrollment_tertiary
# 2641          AFG  1970                     0.76877
# 2645          ARB  1970                     5.96426
# 2647          ARG  1970                    13.24435
# 2651          AUS  1970                    15.81655
# 2658          BGD  1970                     2.13339
# ...           ...   ...                         ...
# 15550         TSA  2018                    24.19059
# 15551         TSS  2018                     9.38955
# 15559         UMC  2018                    53.03968
# 15562         UZB  2018                    10.07635
# 15569         WLD  2018                    38.04186
#
# [7678 rows x 3 columns]

# %%
df.to_csv('../data/converted/school_enrollment_tertiary.csv', index=False)

# %%
df_saved = pd.read_csv('../data/converted/school_enrollment_tertiary.csv')
df_saved
# Out:
#      country_iso  year  school_enrollment_tertiary
# 0            AFG  1970                     0.76877
# 1            ARB  1970                     5.96426
# 2            ARG  1970                    13.24435
# 3            AUS  1970                    15.81655
# 4            BGD  1970                     2.13339
# ...          ...   ...                         ...
# 7673         TSA  2018                    24.19059
# 7674         TSS  2018                     9.38955
# 7675         UMC  2018                    53.03968
# 7676         UZB  2018                    10.07635
# 7677         WLD  2018                    38.04186
#
# [7678 rows x 3 columns]
