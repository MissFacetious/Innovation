# %% [markdown]
# #### CSE 6242 Data for Visual Analytics Innovation TeamTransparency group project
# #### Script to cleanse & convert  Global Innovation Index (gii) csv datasets
# #### 2020-03-22 by Marc Boulet
# #### Based on Ricardo Stamato's *book_conversion* Jupyter notebook

# %%
import pandas as pd
import difflib
pd.set_option('display.max_rows', 300)
pd.set_option('display.max_columns', 100)

# %%
# point to dataset 
dataset = 'gii_creative_goods'
gii = pd.read_csv('../data/' + dataset + '.csv')

# %%
gii.head()
# Out:
#    rank               Economy Income Group(Strength/Weakness)  \
# 0     1                 China                        Strength
# 1     1  Czech Republic (the)                        Strength
# 2     1      Hong Kong, China                        Strength
# 3     1              Malaysia                        Strength
# 4     1                Mexico                        Strength
#
#   Strength / Weakness  Value  Score
# 0            Strength   11.9  100.0
# 1            Strength   10.1  100.0
# 2            Strength    9.9  100.0
# 3            Strength    9.8  100.0
# 4            Strength    9.6  100.0

# %%
# make copy
gii_new = gii.copy()

# %%
# get country codes
countries = pd.read_csv('../data/country-codes_csv.csv')

# %%
def get_country_iso(name):
    p = difflib.get_close_matches(name, countries['official_name_en'].dropna().unique(), n=1, cutoff=0.5)
    if len(p)>0:
        return countries[countries['official_name_en']==p[0]]['ISO3166-1-Alpha-3'].to_list()[0]
    else:
        return ""

# %%
# drop excess columns
gii_new.drop(columns=['rank'], inplace=True)
gii_new.drop(columns=['Income Group(Strength/Weakness)'], inplace=True)
gii_new.drop(columns=['Strength / Weakness'], inplace=True)
gii_new.drop(columns=['Score'], inplace=True)

# add year column (all data reflects 2019 values)
gii_new.insert(0, 'year', 2019, True)

# rename value column
gii_new.rename(columns={'Value': dataset}, inplace=True)

# %%
# assign country codes
gii_new['country_iso'] = [get_country_iso(x) for x in gii_new['Economy']]
#gii_new.sample(10)
gii_new.head(10)
# Out:
#    year               Economy  gii_creative_goods country_iso
# 0  2019                 China                11.9         CHN
# 1  2019  Czech Republic (the)                10.1         COD
# 2  2019      Hong Kong, China                 9.9         MNG
# 3  2019              Malaysia                 9.8         MYS
# 4  2019                Mexico                 9.6         MEX
# 5  2019              Thailand                 8.7         THA
# 6  2019              Slovakia                 8.5         SVK
# 7  2019           Philippines                 7.0         PHL
# 8  2019               Hungary                 6.1         HUN
# 9  2019              Viet Nam                 5.9         VNM

# %%
# check country_iso for unmatched countries
gii_new[gii_new['country_iso']=='']
# Out:
# Empty DataFrame
# Columns: [year, Economy, gii_creative_goods, country_iso]
# Index: []

# %%
# manually change improperly assigned country_iso values
gii_new.loc[gii_new.Economy == 'Czech Republic (the)','country_iso'] = 'CZE'
gii_new.loc[gii_new.Economy == 'Hong Kong, China','country_iso'] = 'HKG'
gii_new.loc[gii_new.Economy == 'North Macedonia','country_iso'] = 'MKD'

# %%
gii_new
# Out:
#      year                            Economy  gii_creative_goods country_iso
# 0    2019                              China                11.9         CHN
# 1    2019               Czech Republic (the)                10.1         CZE
# 2    2019                   Hong Kong, China                 9.9         HKG
# 3    2019                           Malaysia                 9.8         MYS
# 4    2019                             Mexico                 9.6         MEX
# 5    2019                           Thailand                 8.7         THA
# 6    2019                           Slovakia                 8.5         SVK
# 7    2019                        Philippines                 7.0         PHL
# 8    2019                            Hungary                 6.1         HUN
# 9    2019                           Viet Nam                 5.9         VNM
# 10   2019                          Singapore                 4.4         SGP
# 11   2019                             Poland                 4.4         POL
# 12   2019         United Arab Emirates (the)                 4.2         ARE
# 13   2019                  Netherlands (the)                 4.1         NLD
# 14   2019                        Switzerland                 3.8         CHE
# 15   2019            Republic of Korea (the)                 3.6         KOR
# 16   2019     United States of America (the)                 3.3         USA
# 17   2019                             Latvia                 3.1         LVA
# 18   2019                          Indonesia                 2.9         IDN
# 19   2019               United Kingdom (the)                 2.9         GBR
# 20   2019                             Turkey                 2.9         TUR
# 21   2019                              India                 2.7         IND
# 22   2019                             Panama                 2.5         PAN
# 23   2019                              Italy                 2.2         ITA
# 24   2019           Dominican Republic (the)                 2.2         DOM
# 25   2019                            Germany                 2.2         DEU
# 26   2019                              Japan                 2.0         JPN
# 27   2019                            Tunisia                 2.0         TUN
# 28   2019                          Lithuania                 2.0         LTU
# 29   2019                             Sweden                 1.8         SWE
# 30   2019                             Israel                 1.7         ISR
# 31   2019                             France                 1.7         FRA
# 32   2019                            Denmark                 1.6         DNK
# 33   2019                            Belgium                 1.6         BEL
# 34   2019                            Bahrain                 1.5         BHR
# 35   2019                             Jordan                 1.5         JOR
# 36   2019                           Portugal                 1.5         PRT
# 37   2019                            Estonia                 1.4         EST
# 38   2019   Bolivia (Plurinational State of)                 1.3         BOL
# 39   2019                            Ireland                 1.3         IRL
# 40   2019                              Egypt                 1.1         EGY
# 41   2019                             Greece                 1.1         GRC
# 42   2019                             Canada                 1.0         CAN
# 43   2019                           Slovenia                 1.0         SVN
# 44   2019                            Austria                 0.9         AUT
# 45   2019                              Spain                 0.9         ESP
# 46   2019                          Mauritius                 0.9         MUS
# 47   2019                       South Africa                 0.8         ZAF
# 48   2019                           Bulgaria                 0.8         BGR
# 49   2019                            Croatia                 0.8         HRV
# 50   2019                             Serbia                 0.7         SRB
# 51   2019                            Romania                 0.7         ROU
# 52   2019                        El Salvador                 0.7         SLV
# 53   2019                          Australia                 0.6         AUS
# 54   2019                            Armenia                 0.6         ARM
# 55   2019                            Finland                 0.5         FIN
# 56   2019                            Lebanon                 0.5         LBN
# 57   2019                               Oman                 0.5         OMN
# 58   2019                             Cyprus                 0.5         CYP
# 59   2019                             Norway                 0.5         NOR
# 60   2019                        New Zealand                 0.5         NZL
# 61   2019                             Uganda                 0.5         UGA
# 62   2019                            Belarus                 0.4         BLR
# 63   2019                          Sri Lanka                 0.4         LKA
# 64   2019                         Costa Rica                 0.4         CRI
# 65   2019                       Saudi Arabia                 0.4         SAU
# 66   2019             Bosnia and Herzegovina                 0.4         BIH
# 67   2019           Russian Federation (the)                 0.3         RUS
# 68   2019                            Namibia                 0.3         NAM
# 69   2019                               Peru                 0.3         PER
# 70   2019                          Nicaragua                 0.3         NIC
# 71   2019                           Pakistan                 0.3         PAK
# 72   2019                           Zimbabwe                 0.3         ZWE
# 73   2019                          Guatemala                 0.3         GTM
# 74   2019                              Kenya                 0.3         KEN
# 75   2019                           Cambodia                 0.3         KHM
# 76   2019                             Brazil                 0.2         BRA
# 77   2019                             Kuwait                 0.2         KWT
# 78   2019                           Colombia                 0.2         COL
# 79   2019                              Nepal                 0.2         NPL
# 80   2019                              Malta                 0.2         MLT
# 81   2019                            Ukraine                 0.2         UKR
# 82   2019          Republic of Moldova (the)                 0.2         MDA
# 83   2019                            Jamaica                 0.2         JAM
# 84   2019                    North Macedonia                 0.2         MKD
# 85   2019                           Botswana                 0.2         BWA
# 86   2019                             Rwanda                 0.2         RWA
# 87   2019                              Qatar                 0.2         QAT
# 88   2019                            Albania                 0.2         ALB
# 89   2019                              Chile                 0.2         CHL
# 90   2019                  Brunei Darussalam                 0.2         BRN
# 91   2019                Trinidad and Tobago                 0.1         TTO
# 92   2019                         Kazakhstan                 0.1         KAZ
# 93   2019                         Montenegro                 0.1         MNE
# 94   2019                         Madagascar                 0.1         MDG
# 95   2019  United Republic of Tanzania (the)                 0.1         TZA
# 96   2019                            Georgia                 0.1         GEO
# 97   2019                          Argentina                 0.1         ARG
# 98   2019                         Kyrgyzstan                 0.1         KGZ
# 99   2019                         Luxembourg                 0.1         LUX
# 100  2019                            Morocco                 0.1         MAR
# 101  2019                            Senegal                 0.1         SEN
# 102  2019                      Cote d'Ivoire                 0.1         CIV
# 103  2019                             Malawi                 0.1         MWI
# 104  2019                            Iceland                 0.1         ISL
# 105  2019                            Uruguay                 0.1         URY
# 106  2019                         Bangladesh                 0.1         BGD
# 107  2019                           Honduras                 0.1         HND
# 108  2019                            Burundi                 0.1         BDI
# 109  2019                            Ecuador                 0.1         ECU
# 110  2019         Iran (Islamic Republic of)                 0.1         IRN
# 111  2019                               Togo                 0.0         TGO
# 112  2019                        Niger (the)                 0.0         NER
# 113  2019                           Paraguay                 0.0         PRY
# 114  2019                           Ethiopia                 0.0         ETH
# 115  2019                             Zambia                 0.0         ZMB
# 116  2019                              Ghana                 0.0         GHA
# 117  2019                               Mali                 0.0         MLI
# 118  2019                       Burkina Faso                 0.0         BFA
# 119  2019                             Guinea                 0.0         GIN
# 120  2019                           Cameroon                 0.0         CMR
# 121  2019                         Azerbaijan                 0.0         AZE
# 122  2019                              Yemen                 0.0         YEM
# 123  2019                            Algeria                 0.0         DZA
# 124  2019                           Mongolia                 0.0         MNG
# 125  2019                            Nigeria                 0.0         NGA
# 126  2019                         Mozambique                 0.0         MOZ
# 127  2019                              Benin                 0.0         BEN

# %%
# remove Economy column after QC
gii_new.drop(columns=['Economy'], inplace=True)

# %%
gii_new.to_csv('../data/converted/' + dataset + '.csv', index=False)

# %%
gii_saved = pd.read_csv('../data/converted/' + dataset + '.csv')
gii_saved
# Out:
#      year  gii_creative_goods country_iso
# 0    2019                11.9         CHN
# 1    2019                10.1         CZE
# 2    2019                 9.9         HKG
# 3    2019                 9.8         MYS
# 4    2019                 9.6         MEX
# 5    2019                 8.7         THA
# 6    2019                 8.5         SVK
# 7    2019                 7.0         PHL
# 8    2019                 6.1         HUN
# 9    2019                 5.9         VNM
# 10   2019                 4.4         SGP
# 11   2019                 4.4         POL
# 12   2019                 4.2         ARE
# 13   2019                 4.1         NLD
# 14   2019                 3.8         CHE
# 15   2019                 3.6         KOR
# 16   2019                 3.3         USA
# 17   2019                 3.1         LVA
# 18   2019                 2.9         IDN
# 19   2019                 2.9         GBR
# 20   2019                 2.9         TUR
# 21   2019                 2.7         IND
# 22   2019                 2.5         PAN
# 23   2019                 2.2         ITA
# 24   2019                 2.2         DOM
# 25   2019                 2.2         DEU
# 26   2019                 2.0         JPN
# 27   2019                 2.0         TUN
# 28   2019                 2.0         LTU
# 29   2019                 1.8         SWE
# 30   2019                 1.7         ISR
# 31   2019                 1.7         FRA
# 32   2019                 1.6         DNK
# 33   2019                 1.6         BEL
# 34   2019                 1.5         BHR
# 35   2019                 1.5         JOR
# 36   2019                 1.5         PRT
# 37   2019                 1.4         EST
# 38   2019                 1.3         BOL
# 39   2019                 1.3         IRL
# 40   2019                 1.1         EGY
# 41   2019                 1.1         GRC
# 42   2019                 1.0         CAN
# 43   2019                 1.0         SVN
# 44   2019                 0.9         AUT
# 45   2019                 0.9         ESP
# 46   2019                 0.9         MUS
# 47   2019                 0.8         ZAF
# 48   2019                 0.8         BGR
# 49   2019                 0.8         HRV
# 50   2019                 0.7         SRB
# 51   2019                 0.7         ROU
# 52   2019                 0.7         SLV
# 53   2019                 0.6         AUS
# 54   2019                 0.6         ARM
# 55   2019                 0.5         FIN
# 56   2019                 0.5         LBN
# 57   2019                 0.5         OMN
# 58   2019                 0.5         CYP
# 59   2019                 0.5         NOR
# 60   2019                 0.5         NZL
# 61   2019                 0.5         UGA
# 62   2019                 0.4         BLR
# 63   2019                 0.4         LKA
# 64   2019                 0.4         CRI
# 65   2019                 0.4         SAU
# 66   2019                 0.4         BIH
# 67   2019                 0.3         RUS
# 68   2019                 0.3         NAM
# 69   2019                 0.3         PER
# 70   2019                 0.3         NIC
# 71   2019                 0.3         PAK
# 72   2019                 0.3         ZWE
# 73   2019                 0.3         GTM
# 74   2019                 0.3         KEN
# 75   2019                 0.3         KHM
# 76   2019                 0.2         BRA
# 77   2019                 0.2         KWT
# 78   2019                 0.2         COL
# 79   2019                 0.2         NPL
# 80   2019                 0.2         MLT
# 81   2019                 0.2         UKR
# 82   2019                 0.2         MDA
# 83   2019                 0.2         JAM
# 84   2019                 0.2         MKD
# 85   2019                 0.2         BWA
# 86   2019                 0.2         RWA
# 87   2019                 0.2         QAT
# 88   2019                 0.2         ALB
# 89   2019                 0.2         CHL
# 90   2019                 0.2         BRN
# 91   2019                 0.1         TTO
# 92   2019                 0.1         KAZ
# 93   2019                 0.1         MNE
# 94   2019                 0.1         MDG
# 95   2019                 0.1         TZA
# 96   2019                 0.1         GEO
# 97   2019                 0.1         ARG
# 98   2019                 0.1         KGZ
# 99   2019                 0.1         LUX
# 100  2019                 0.1         MAR
# 101  2019                 0.1         SEN
# 102  2019                 0.1         CIV
# 103  2019                 0.1         MWI
# 104  2019                 0.1         ISL
# 105  2019                 0.1         URY
# 106  2019                 0.1         BGD
# 107  2019                 0.1         HND
# 108  2019                 0.1         BDI
# 109  2019                 0.1         ECU
# 110  2019                 0.1         IRN
# 111  2019                 0.0         TGO
# 112  2019                 0.0         NER
# 113  2019                 0.0         PRY
# 114  2019                 0.0         ETH
# 115  2019                 0.0         ZMB
# 116  2019                 0.0         GHA
# 117  2019                 0.0         MLI
# 118  2019                 0.0         BFA
# 119  2019                 0.0         GIN
# 120  2019                 0.0         CMR
# 121  2019                 0.0         AZE
# 122  2019                 0.0         YEM
# 123  2019                 0.0         DZA
# 124  2019                 0.0         MNG
# 125  2019                 0.0         NGA
# 126  2019                 0.0         MOZ
# 127  2019                 0.0         BEN
