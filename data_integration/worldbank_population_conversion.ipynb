# %%
import pandas as pd
import difflib
pd.set_option('display.max_rows', 300)
pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv('../data/population.csv', skiprows=4)

# %%
df.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996973.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5454933.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965        1966  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0     57715.0
# 1  9169410.0  9351441.0  9543205.0  9744781.0  9956320.0  10174836.0
# 2  5531472.0  5608539.0  5679458.0  5735044.0  5770570.0   5781214.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0   1914573.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0     19647.0
#
#          1967        1968        1969        1970        1971        1972  \
# ...

# %%
df.drop(columns=['Country Name', 'Indicator Name', 'Indicator Code'], inplace=True)

# %%
df.rename(columns={'Country Code': 'country_iso'}, inplace=True)

# %%
df = df.melt(id_vars=["country_iso"], var_name="year", value_name="population")
df
# Out:
#       country_iso         year  population
# 0             ABW         1960     54211.0
# 1             AFG         1960   8996973.0
# 2             AGO         1960   5454933.0
# 3             ALB         1960   1608800.0
# 4             AND         1960     13411.0
# ...           ...          ...         ...
# 16099         XKX  Unnamed: 64         NaN
# 16100         YEM  Unnamed: 64         NaN
# 16101         ZAF  Unnamed: 64         NaN
# 16102         ZMB  Unnamed: 64         NaN
# 16103         ZWE  Unnamed: 64         NaN
#
# [16104 rows x 3 columns]

# %%
df.dropna(inplace=True)
df
# Out:
#       country_iso  year  population
# 0             ABW  1960     54211.0
# 1             AFG  1960   8996973.0
# 2             AGO  1960   5454933.0
# 3             ALB  1960   1608800.0
# 4             AND  1960     13411.0
# ...           ...   ...         ...
# 15571         XKX  2018   1845300.0
# 15572         YEM  2018  28498687.0
# 15573         ZAF  2018  57779622.0
# 15574         ZMB  2018  17351822.0
# 15575         ZWE  2018  14439018.0
#
# [15409 rows x 3 columns]

# %%
df.to_csv('../data/converted/population.csv', index=False)

# %%
df_saved = pd.read_csv('../data/converted/population.csv')
df_saved
# Out:
#       country_iso  year  population
# 0             ABW  1960     54211.0
# 1             AFG  1960   8996973.0
# 2             AGO  1960   5454933.0
# 3             ALB  1960   1608800.0
# 4             AND  1960     13411.0
# ...           ...   ...         ...
# 15404         XKX  2018   1845300.0
# 15405         YEM  2018  28498687.0
# 15406         ZAF  2018  57779622.0
# 15407         ZMB  2018  17351822.0
# 15408         ZWE  2018  14439018.0
#
# [15409 rows x 3 columns]
