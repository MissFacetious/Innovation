# %%
import pandas as pd
import difflib
pd.set_option('display.max_rows', 300)
pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv('../data/literacy_rate.csv', skiprows=4)

# %%
df.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Literacy rate, adult total (% of people ages 1...  SE.ADT.LITR.ZS   NaN
# 1  Literacy rate, adult total (% of people ages 1...  SE.ADT.LITR.ZS   NaN
# 2  Literacy rate, adult total (% of people ages 1...  SE.ADT.LITR.ZS   NaN
# 3  Literacy rate, adult total (% of people ages 1...  SE.ADT.LITR.ZS   NaN
# 4  Literacy rate, adult total (% of people ages 1...  SE.ADT.LITR.ZS   NaN
#
#    1961  1962  1963  1964  1965  1966  1967  1968  1969  1970  1971  1972  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
df.drop(columns=['Country Name', 'Indicator Name', 'Indicator Code'], inplace=True)

# %%
df.rename(columns={'Country Code': 'country_iso'}, inplace=True)

# %%
df = df.melt(id_vars=["country_iso"], var_name="year", value_name="literacy_rate")
df
# Out:
#       country_iso  year  literacy_rate
# 0             ABW  1960            NaN
# 1             AFG  1960            NaN
# 2             AGO  1960            NaN
# 3             ALB  1960            NaN
# 4             AND  1960            NaN
# ...           ...   ...            ...
# 15835         XKX  2019            NaN
# 15836         YEM  2019            NaN
# 15837         ZAF  2019            NaN
# 15838         ZMB  2019            NaN
# 15839         ZWE  2019            NaN
#
# [15840 rows x 3 columns]

# %%
df.dropna(inplace=True)
df
# Out:
#       country_iso  year  literacy_rate
# 2668          BRB  1970      99.268082
# 2728          GRD  1970      97.794472
# 2891          VCT  1970      95.632156
# 3327          MNA  1972      39.386101
# 3379          SOM  1972       5.404650
# ...           ...   ...            ...
# 15567         VNM  2018      95.000380
# 15568         VUT  2018      87.506310
# 15569         WLD  2018      86.301010
# 15570         WSM  2018      99.095770
# 15574         ZMB  2018      86.747960
#
# [2445 rows x 3 columns]

# %%
df.to_csv('../data/converted/literacy_rate.csv', index=False)

# %%
df_saved = pd.read_csv('../data/converted/literacy_rate.csv')
df_saved
# Out:
#      country_iso  year  literacy_rate
# 0            BRB  1970      99.268082
# 1            GRD  1970      97.794472
# 2            VCT  1970      95.632156
# 3            MNA  1972      39.386101
# 4            SOM  1972       5.404650
# ...          ...   ...            ...
# 2440         VNM  2018      95.000380
# 2441         VUT  2018      87.506310
# 2442         WLD  2018      86.301010
# 2443         WSM  2018      99.095770
# 2444         ZMB  2018      86.747960
#
# [2445 rows x 3 columns]
