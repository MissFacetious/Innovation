# %%
import pandas as pd
pd.set_option('display.max_rows', 300)
pd.set_option('display.max_columns', 100)

# %%
import glob

def check_required_columns(df):
    return df.columns.contains('year') and df.columns.contains('country_iso')

def check_unicity(df):
    return df.groupby(['country_iso', 'year']).count().max().to_list()[0] <= 1

def sanity_check(df, filename):
    if not check_required_columns(df):
        print(f'{filename} does not have required columns: {df.columns}')
        return
    if not check_unicity(df):
        print(f'{filename} has duplicate country|year rows')
        return
    print(f'{filename} OK')

# %%
path = r'../data/converted' # use your path
all_files = glob.glob(path + "/*.csv")
dfs = []
for filename in all_files:
    dfs.append(pd.read_csv(filename))

# %%
for i, df in enumerate(dfs):
    sanity_check(df, all_files[i])
# Out:
# ../data/converted/gii_human_capital.csv OK
# ../data/converted/gii_domestic_credit.csv OK
# ../data/converted/mobile_subscriptions.csv OK
# ../data/converted/broadband_subscriptions.csv OK
# ../data/converted/gii_ict_services_imports.csv OK
# ../data/converted/diversity_published.csv OK
# ../data/converted/literacy_rate.csv OK
# ../data/converted/electrification.csv OK
# ../data/converted/gii_scientific_publications.csv OK
# ../data/converted/books_published.csv OK
# ../data/converted/rd_in_gdp.csv OK
# ../data/converted/creative_services.csv OK
# ../data/converted/rural_population.csv OK
# ../data/converted/school_enrollment_tertiary.csv OK
# ../data/converted/gii_creative_services.csv OK
# ../data/converted/gii_rule_of_law.csv OK
# ../data/converted/population.csv OK
# ../data/converted/mortality_rate.csv OK
# ../data/converted/secure_internet_servers.csv OK
# ../data/converted/gii_institutions.csv OK
# ../data/converted/gii_top_level_domains.csv OK
# ../data/converted/gii_patent_applications.csv OK
# ../data/converted/feature_films.csv OK
# ../data/converted/gii_patent_families.csv OK
# ../data/converted/gii_mobile_apps.csv OK
# ../data/converted/gii_research_talent_in_business.csv OK
# ../data/converted/cultural_occupation.csv OK
# ../data/converted/gii_creative_goods.csv OK
# ../data/converted/life_expectancy.csv OK
# ../data/converted/ease_of_business.csv OK
# ../data/converted/gii_wikipedia_edits.csv OK
# ../data/converted/gii_ict_access.csv OK
# ../data/converted/gii_stem_assessment.csv OK
# ../data/converted/poverty_ratio.csv OK
# ../data/converted/foreign_investment.csv OK
# ../data/converted/hospitals.csv OK
# ../data/converted/gii_university_industry.csv OK
# ../data/converted/gii_innovation_output.csv OK
# ../data/converted/gdp_per_capta.csv OK
# ../data/converted/global_innovation_index.csv OK
# /Users/ricardostamato/miniconda3/envs/ml/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: The 'contains' method is deprecated and will be removed in a future version. Use 'key in index' instead of 'index.contains(key)'
#   after removing the cwd from sys.path.

# %%
dfs = []

merged = pd.read_csv(all_files[0], index_col=None)

for filename in all_files[1:]:
    df = pd.read_csv(filename, index_col=None)
    merged = merged.merge(df, on=['country_iso', 'year'], how='outer', sort=True)
    print('merged ok for ' + filename)
# Out:
# merged ok for ../data/converted/gii_domestic_credit.csv
# merged ok for ../data/converted/mobile_subscriptions.csv
# merged ok for ../data/converted/broadband_subscriptions.csv
# merged ok for ../data/converted/gii_ict_services_imports.csv
# merged ok for ../data/converted/diversity_published.csv
# merged ok for ../data/converted/literacy_rate.csv
# merged ok for ../data/converted/electrification.csv
# merged ok for ../data/converted/gii_scientific_publications.csv
# merged ok for ../data/converted/books_published.csv
# merged ok for ../data/converted/rd_in_gdp.csv
# merged ok for ../data/converted/creative_services.csv
# merged ok for ../data/converted/rural_population.csv
# merged ok for ../data/converted/school_enrollment_tertiary.csv
# merged ok for ../data/converted/gii_creative_services.csv
# merged ok for ../data/converted/gii_rule_of_law.csv
# merged ok for ../data/converted/population.csv
# merged ok for ../data/converted/mortality_rate.csv
# merged ok for ../data/converted/secure_internet_servers.csv
# merged ok for ../data/converted/gii_institutions.csv
# merged ok for ../data/converted/gii_top_level_domains.csv
# merged ok for ../data/converted/gii_patent_applications.csv
# merged ok for ../data/converted/feature_films.csv
# merged ok for ../data/converted/gii_patent_families.csv
# merged ok for ../data/converted/gii_mobile_apps.csv
# merged ok for ../data/converted/gii_research_talent_in_business.csv
# merged ok for ../data/converted/cultural_occupation.csv
# merged ok for ../data/converted/gii_creative_goods.csv
# merged ok for ../data/converted/life_expectancy.csv
# merged ok for ../data/converted/ease_of_business.csv
# merged ok for ../data/converted/gii_wikipedia_edits.csv
# merged ok for ../data/converted/gii_ict_access.csv
# merged ok for ../data/converted/gii_stem_assessment.csv
# merged ok for ../data/converted/poverty_ratio.csv
# merged ok for ../data/converted/foreign_investment.csv
# merged ok for ../data/converted/hospitals.csv
# merged ok for ../data/converted/gii_university_industry.csv
# merged ok for ../data/converted/gii_innovation_output.csv
# merged ok for ../data/converted/gdp_per_capta.csv
# merged ok for ../data/converted/global_innovation_index.csv

# %%
merged.groupby(['country_iso', 'year'])['country_iso'].count().sort_values(ascending=False)
# Out:
# country_iso  year
# ZWE          2020    1
# GRC          1967    1
#              1965    1
#              1964    1
#              1963    1
#                     ..
# NOR          1971    1
#              1970    1
#              1969    1
#              1968    1
# ABW          1960    1
# Name: country_iso, Length: 15833, dtype: int64

# %%
merged.shape
# Out:
# (15833, 49)

# %%
merged['country_iso'].unique().size
# Out:
# 271

# %%
merged[merged.isna().all(axis=1)].index.size
# Out:
# 0

# %%
merged.to_csv('../data/converted/merged.csv', index=False)

# %%
df_saved = pd.read_csv('../data/converted/merged.csv')
df_saved
# Out:
#        year  gii_human_capital country_iso  gii_domestic_credit  \
# 0      1960                NaN         ABW                  NaN
# 1      1961                NaN         ABW                  NaN
# 2      1962                NaN         ABW                  NaN
# 3      1963                NaN         ABW                  NaN
# 4      1964                NaN         ABW                  NaN
# ...     ...                ...         ...                  ...
# 15828  2016                NaN         ZWE                  NaN
# 15829  2017                NaN         ZWE                  NaN
# 15830  2018                NaN         ZWE                  NaN
# 15831  2019               27.8         ZWE                  NaN
# 15832  2020                NaN         ZWE                  NaN
#
#        mobile_subscriptions  broadband_subscriptions_per100  \
# 0                  0.000000                             NaN
# 1                       NaN                             NaN
# 2                       NaN                             NaN
# 3                       NaN                             NaN
# 4                       NaN                             NaN
# ...                     ...                             ...
# 15828             91.793458                        1.217633
# 15829             98.985073                        1.315694
# 15830             89.404869                        1.406322
# 15831                   NaN                             NaN
# 15832                   NaN                             NaN
#
#        gii_ict_services_imports  diversity_ethnicFractionalization  \
# 0                           NaN                                NaN
# 1                           NaN                                NaN
# 2                           NaN                                NaN
# 3                           NaN                                NaN
# 4                           NaN                                NaN
# ...                         ...                                ...
# 15828                       NaN                                NaN
# 15829                       NaN                                NaN
# 15830                       NaN                                NaN
# 15831                       0.9                                NaN
# 15832                       NaN                             0.3874
#
#        diversity_linguisticFractionalization  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 15828                                    NaN
# 15829                                    NaN
# 15830                                    NaN
# 15831                                    NaN
# 15832                                 0.4472
#
#        diversity_religiousFractionalization  literacy_rate  electrification  \
# 0                                       NaN            NaN              NaN
# 1                                       NaN            NaN              NaN
# 2                                       NaN            NaN              NaN
# 3                                       NaN            NaN              NaN
# 4                                       NaN            NaN              NaN
# ...                                     ...            ...              ...
# 15828                                   NaN            NaN        39.892345
# 15829                                   NaN            NaN        40.421368
# 15830                                   NaN            NaN              NaN
# 15831                                   NaN            NaN              NaN
# 15832                                0.7363            NaN              NaN
#
#        gii_scientific_publications book_titles  rd_in_gdp  \
# 0                              NaN         NaN        NaN
# 1                              NaN         NaN        NaN
# 2                              NaN         NaN        NaN
# 3                              NaN         NaN        NaN
# 4                              NaN         NaN        NaN
# ...                            ...         ...        ...
# 15828                          NaN         NaN        NaN
# 15829                          NaN         NaN        NaN
# 15830                          NaN         NaN        NaN
# 15831                          7.0         NaN        NaN
# 15832                          NaN         NaN        NaN
#
#        creative_svc_audiovisual  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 15828                       NaN
# 15829                       NaN
# 15830                       NaN
# 15831                       NaN
# 15832                       NaN
#
#        creative_svc_other_personal_cultural_recreational  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15828                                                NaN
# 15829                                                NaN
# 15830                                                NaN
# 15831                                                NaN
# 15832                                                NaN
#
#        creative_svc_advertising_mktresearch_polling  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 15828                                           NaN
# 15829                                           NaN
# 15830                                           NaN
# 15831                                           NaN
# 15832                                           NaN
#
#        creative_svc_architectural_engineering_technical  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 15828                                               NaN
# 15829                                               NaN
# 15830                                               NaN
# 15831                                               NaN
# 15832                                               NaN
#
#        creative_svc_personal_cultural_recreational  creative_svc_research  \
# 0                                              NaN                    NaN
# 1                                              NaN                    NaN
# 2                                              NaN                    NaN
# 3                                              NaN                    NaN
# 4                                              NaN                    NaN
# ...                                            ...                    ...
# 15828                                          NaN                    NaN
# 15829                                          NaN                    NaN
# 15830                                          NaN                    NaN
# 15831                                          NaN                    NaN
# 15832                                          NaN                    NaN
#
#        rural_population  school_enrollment_tertiary  gii_creative_services  \
# 0                   NaN                         NaN                    NaN
# 1                   NaN                         NaN                    NaN
# 2                   NaN                         NaN                    NaN
# 3                   NaN                         NaN                    NaN
# 4                   NaN                         NaN                    NaN
# ...                 ...                         ...                    ...
# 15828            67.704                         NaN                    NaN
# 15829            67.763                         NaN                    NaN
# 15830            67.791                         NaN                    NaN
# 15831               NaN                         NaN                    0.2
# 15832               NaN                         NaN                    NaN
#
#        gii_rule_of_law  population  mortality_rate  secure_internet_servers  \
# 0                  NaN     54211.0             NaN                      NaN
# 1                  NaN     55438.0             NaN                      NaN
# 2                  NaN     56225.0             NaN                      NaN
# 3                  NaN     56695.0             NaN                      NaN
# 4                  NaN     57032.0             NaN                      NaN
# ...                ...         ...             ...                      ...
# 15828              NaN  14030390.0            36.3                13.827128
# 15829              NaN  14236745.0            35.4                30.554737
# 15830              NaN  14439018.0            33.9                46.609818
# 15831             -1.4         NaN             NaN                      NaN
# 15832              NaN         NaN             NaN                      NaN
#
#        gii_institutions  gii_top_level_domains  gii_patent_applications  \
# 0                   NaN                    NaN                      NaN
# 1                   NaN                    NaN                      NaN
# 2                   NaN                    NaN                      NaN
# 3                   NaN                    NaN                      NaN
# 4                   NaN                    NaN                      NaN
# ...                 ...                    ...                      ...
# 15828               NaN                    NaN                      NaN
# 15829               NaN                    NaN                      NaN
# 15830               NaN                    NaN                      NaN
# 15831              37.6                    1.1                      0.2
# 15832               NaN                    NaN                      NaN
#
#        feature_films_produced  gii_patent_families  gii_mobile_apps  \
# 0                         NaN                  NaN              NaN
# 1                         NaN                  NaN              NaN
# 2                         NaN                  NaN              NaN
# 3                         NaN                  NaN              NaN
# 4                         NaN                  NaN              NaN
# ...                       ...                  ...              ...
# 15828                     NaN                  NaN              NaN
# 15829                     NaN                  NaN              NaN
# 15830                     NaN                  NaN              NaN
# 15831                     NaN                  0.0              NaN
# 15832                     NaN                  NaN              NaN
#
#        gii_research_talent_in_business  cultural_occupation  \
# 0                                  NaN                  NaN
# 1                                  NaN                  NaN
# 2                                  NaN                  NaN
# 3                                  NaN                  NaN
# 4                                  NaN                  NaN
# ...                                ...                  ...
# 15828                              NaN                  NaN
# 15829                              NaN                  NaN
# 15830                              NaN                  NaN
# 15831                              NaN                  NaN
# 15832                              NaN                  NaN
#
#        gii_creative_goods  life_expectancy  ease_of_business  \
# 0                     NaN              NaN               NaN
# 1                     NaN              NaN               NaN
# 2                     NaN              NaN               NaN
# 3                     NaN              NaN               NaN
# 4                     NaN              NaN               NaN
# ...                   ...              ...               ...
# 15828                 NaN           60.294               NaN
# 15829                 NaN           60.812               NaN
# 15830                 NaN              NaN               NaN
# 15831                 0.3              NaN             140.0
# 15832                 NaN              NaN               NaN
#
#        gii_wikipedia_edits  gii_ict_access  gii_stem_assessment  \
# 0                      NaN             NaN                  NaN
# 1                      NaN             NaN                  NaN
# 2                      NaN             NaN                  NaN
# 3                      NaN             NaN                  NaN
# 4                      NaN             NaN                  NaN
# ...                    ...             ...                  ...
# 15828                  NaN             NaN                  NaN
# 15829                  NaN             NaN                  NaN
# 15830                  NaN             NaN                  NaN
# 15831                  0.3             3.6                  NaN
# 15832                  NaN             NaN                  NaN
#
#        poverty_ratio  foreign_investment  total_hospital_density_per_100k  \
# 0                NaN                 NaN                              NaN
# 1                NaN                 NaN                              NaN
# 2                NaN                 NaN                              NaN
# 3                NaN                 NaN                              NaN
# 4                NaN                 NaN                              NaN
# ...              ...                 ...                              ...
# 15828            NaN            1.669274                              NaN
# 15829            NaN            1.083538                              NaN
# 15830            NaN            2.402015                              NaN
# 15831            NaN                 NaN                              NaN
# 15832            NaN                 NaN                              NaN
#
#        gii_university_industry  gii_innovation_output  gdp_per_capta_usd  \
# 0                          NaN                    NaN                NaN
# 1                          NaN                    NaN                NaN
# 2                          NaN                    NaN                NaN
# 3                          NaN                    NaN                NaN
# 4                          NaN                    NaN                NaN
# ...                        ...                    ...                ...
# 15828                      NaN                    NaN         1464.58353
# 15829                      NaN                    NaN         1602.40351
# 15830                      NaN                    NaN         2146.99638
# 15831                      2.6                   15.4                NaN
# 15832                      NaN                    NaN                NaN
#
#        global_innovation_index
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 15828                      NaN
# 15829                      NaN
# 15830                      NaN
# 15831                     22.3
# 15832                      NaN
#
# [15833 rows x 49 columns]
