# %%
import pandas as pd
import difflib
pd.set_option('display.max_rows', 300)
pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv('../data/ease_of_business.csv', skiprows=4)

# %%
df.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Ease of doing business index (1=most business-...  IC.BUS.EASE.XQ   NaN
# 1  Ease of doing business index (1=most business-...  IC.BUS.EASE.XQ   NaN
# 2  Ease of doing business index (1=most business-...  IC.BUS.EASE.XQ   NaN
# 3  Ease of doing business index (1=most business-...  IC.BUS.EASE.XQ   NaN
# 4  Ease of doing business index (1=most business-...  IC.BUS.EASE.XQ   NaN
#
#    1961  1962  1963  1964  1965  1966  1967  1968  1969  1970  1971  1972  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
df = df[['Country Code', '2019']]

# %%
df['year'] = 2019
df.rename(columns={'Country Code': 'country_iso', '2019': 'ease_of_business'}, inplace=True)
df
# Out:
#     country_iso  ease_of_business  year
# 0           ABW               NaN  2019
# 1           AFG             173.0  2019
# 2           AGO             177.0  2019
# 3           ALB              82.0  2019
# 4           AND               NaN  2019
# 5           ARB               NaN  2019
# 6           ARE              16.0  2019
# 7           ARG             126.0  2019
# 8           ARM              47.0  2019
# 9           ASM               NaN  2019
# 10          ATG             113.0  2019
# 11          AUS              14.0  2019
# 12          AUT              27.0  2019
# 13          AZE              34.0  2019
# 14          BDI             166.0  2019
# 15          BEL              46.0  2019
# 16          BEN             149.0  2019
# 17          BFA             151.0  2019
# 18          BGD             168.0  2019
# 19          BGR              61.0  2019
# 20          BHR              43.0  2019
# 21          BHS             119.0  2019
# ...

# %%
df.dropna(inplace=True)

# %%
df.to_csv('../data/converted/ease_of_business.csv', index=False)

# %%
df_saved = pd.read_csv('../data/converted/ease_of_business.csv')
df_saved
# Out:
#     country_iso  ease_of_business  year
# 0           AFG             173.0  2019
# 1           AGO             177.0  2019
# 2           ALB              82.0  2019
# 3           ARE              16.0  2019
# 4           ARG             126.0  2019
# 5           ARM              47.0  2019
# 6           ATG             113.0  2019
# 7           AUS              14.0  2019
# 8           AUT              27.0  2019
# 9           AZE              34.0  2019
# 10          BDI             166.0  2019
# 11          BEL              46.0  2019
# 12          BEN             149.0  2019
# 13          BFA             151.0  2019
# 14          BGD             168.0  2019
# 15          BGR              61.0  2019
# 16          BHR              43.0  2019
# 17          BHS             119.0  2019
# 18          BIH              90.0  2019
# 19          BLR              49.0  2019
# 20          BLZ             135.0  2019
# 21          BOL             150.0  2019
# ...
