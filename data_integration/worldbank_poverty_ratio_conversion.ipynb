# %%
import pandas as pd
import difflib
pd.set_option('display.max_rows', 300)
pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv('../data/poverty_ratio.csv', skiprows=4)

# %%
df.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name Indicator Code  1960  \
# 0  Poverty headcount ratio at $1.90 a day (2011 P...    SI.POV.DDAY   NaN
# 1  Poverty headcount ratio at $1.90 a day (2011 P...    SI.POV.DDAY   NaN
# 2  Poverty headcount ratio at $1.90 a day (2011 P...    SI.POV.DDAY   NaN
# 3  Poverty headcount ratio at $1.90 a day (2011 P...    SI.POV.DDAY   NaN
# 4  Poverty headcount ratio at $1.90 a day (2011 P...    SI.POV.DDAY   NaN
#
#    1961  1962  1963  1964  1965  1966  1967  1968  1969  1970  1971  1972  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
df.drop(columns=['Country Name', 'Indicator Name', 'Indicator Code'], inplace=True)

# %%
df.rename(columns={'Country Code': 'country_iso'}, inplace=True)

# %%
df = df.melt(id_vars=["country_iso"], var_name="year", value_name="poverty_ratio")
df
# Out:
#       country_iso         year  poverty_ratio
# 0             ABW         1960            NaN
# 1             AFG         1960            NaN
# 2             AGO         1960            NaN
# 3             ALB         1960            NaN
# 4             AND         1960            NaN
# ...           ...          ...            ...
# 16099         XKX  Unnamed: 64            NaN
# 16100         YEM  Unnamed: 64            NaN
# 16101         ZAF  Unnamed: 64            NaN
# 16102         ZMB  Unnamed: 64            NaN
# 16103         ZWE  Unnamed: 64            NaN
#
# [16104 rows x 3 columns]

# %%
df.dropna(inplace=True)
df
# Out:
#       country_iso  year  poverty_ratio
# 4595          IND  1977           61.6
# 5129          ISR  1979            0.0
# 5199          PAN  1979            8.1
# 5265          USA  1979            0.5
# 5287          ARG  1980            0.4
# ...           ...   ...            ...
# 15241         PRY  2017            1.2
# 15257         SLV  2017            1.9
# 15279         THA  2017            0.0
# 15296         URY  2017            0.1
# 15307         XKX  2017            0.2
#
# [1675 rows x 3 columns]

# %%
df.to_csv('../data/converted/poverty_ratio.csv', index=False)

# %%
df_saved = pd.read_csv('../data/converted/poverty_ratio.csv')
df_saved
# Out:
#      country_iso  year  poverty_ratio
# 0            IND  1977           61.6
# 1            ISR  1979            0.0
# 2            PAN  1979            8.1
# 3            USA  1979            0.5
# 4            ARG  1980            0.4
# ...          ...   ...            ...
# 1670         PRY  2017            1.2
# 1671         SLV  2017            1.9
# 1672         THA  2017            0.0
# 1673         URY  2017            0.1
# 1674         XKX  2017            0.2
#
# [1675 rows x 3 columns]
